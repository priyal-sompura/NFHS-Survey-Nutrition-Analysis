# %%
import pandas as pd

# %%
claims_rename = {
    'Sl. No.': 'sl_no',
    'State/UT': 'state_ut',
    'Claims Submitted Count - 2020-21': 'claims_sub_2020_21',
    'Claims Paid Count - 2020-21': 'claims_paid_2020_21',
    'Claims Pending Count - 2020-21': 'claims_pend_2020_21',
    'Claims Submitted Count - 2021-22': 'claims_sub_2021_22',
    'Claims Paid Count - 2021-22': 'claims_paid_2021_22',
    'Claims Pending Count - 2021-22': 'claims_pend_2021_22',
    'Claims Submitted Count - 2022-23': 'claims_sub_2022_23',
    'Claims Paid Count - 2022-23': 'claims_paid_2022_23',
    'Claims Pending Count - 2022-23': 'claims_pend_2022_23'
}

# %%
claims = pd.read_csv('claims.csv')
claims = claims.rename(columns=claims_rename).drop(columns=['sl_no'], errors='ignore')

# %%
claims.head()
# Out:
#                       state_ut  claims_sub_2020_21  claims_paid_2020_21  \
# 0  Andaman and Nicobar Islands               307.0                287.0
# 1               Andhra Pradesh            411343.0             400241.0
# 2            Arunachal Pradesh                42.0                 35.0
# 3                        Assam             92083.0              91406.0
# 4                        Bihar             83214.0              80494.0
#
#    claims_pend_2020_21  claims_sub_2021_22  claims_paid_2021_22  \
# 0                  NaN                 753                  659
# 1                  NaN              631389               600784
# 2                  4.0                  45                   40
# 3                539.0              173866               171850
# 4                370.0              112312               110554
#
#    claims_pend_2021_22  claims_sub_2022_23  claims_paid_2022_23  \
# 0                  NaN                 663                  629
# ...

# %%
poshan_rename = {
    'Sl. No.': 'sl_no',
    'State/UT-wise': 'state_ut',
    'October 2022 - Stunted (%)': 'stunted_oct2022',
    'October 2022 - Wasted (%)': 'wasted_oct2022',
    'October 2022 - Underweight (%)': 'underweight_oct2022',
    'October 2023 - Stunted (%)': 'stunted_oct2023',
    'October 2023 - Wasted (%)': 'wasted_oct2023',
    'October 2023 - Underweight (%)': 'underweight_oct2023',
    'October 2024 - Stunted (%)': 'stunted_oct2024',
    'October 2024 - Wasted (%)': 'wasted_oct2024',
    'October 2024 - Underweight (%)': 'underweight_oct2024'
}

# %%
poshan = pd.read_csv('poshan_recent_state_nutrition.csv')
poshan = poshan.rename(columns=poshan_rename).drop(columns=['sl_no'], errors='ignore')

# %%
poshan.head()
# Out:
#             state_ut  stunted_oct2022  wasted_oct2022  underweight_oct2022  \
# 0     Andhra Pradesh             21.2             5.3                 10.5
# 1  Arunachal Pradesh             33.3             5.3                 14.6
# 2              Assam             39.0             8.2                 19.0
# 3              Bihar             42.9            11.0                 25.8
# 4       Chhattisgarh             39.0            10.4                 17.9
#
#    stunted_oct2023  wasted_oct2023  underweight_oct2023  stunted_oct2024  \
# 0             18.2             5.4                  8.7             22.6
# 1             27.2             4.6                  9.1             32.7
# 2             39.0             5.0                 15.9             42.4
# 3             45.0             9.0                 22.7             43.8
# 4             29.4            11.3                 15.5             21.5
#
#    wasted_oct2024  underweight_oct2024
# ...

# %%
infra_rename = {
    'Sl. No.': 'sl_no',
    'State/UT': 'state_ut',
    'PHC': 'phc',
    'CHC': 'chc',
    'SUB DISTRICT/ SUB DIVISIONAL HOSPITAL': 'sub_district_hosp',
    'DISTRICT HOSPITAL': 'district_hosp',
    'MEDICAL COLLEGE': 'medical_college',
    'Total No. of Beds': 'total_beds'
}

# %%
infra = pd.read_csv('health_infrastructure_state.csv')
infra = infra.rename(columns=infra_rename).drop(columns=['sl_no'], errors='ignore')

# %%
state_detailed_rename = {
    'States/UTs': 'state_ut',
    'Area': 'area',                          # Urban / Rural / Total
    'Households surveyed': 'hh_surveyed',
    'Women age 15-49 years interviewed': 'women_15_49',
    'Men age 15-54 years interviewed': 'men_15_54',
    
    # Basic Demographics & Infrastructure
    'Female population age 6 years and above who ever attended school (%)': 'female_school_6plus',
    'Population below age 15 years (%)': 'pop_below_15',
    'Sex ratio of the total population (females per 1,000 males)': 'sex_ratio_total',
    'Sex ratio at birth for children born in the last five years (females per 1,000 males)': 'sex_ratio_birth',
    'Children under age 5 years whose birth was registered with the civil authority (%)': 'birth_registered',
    'Deaths in the last 3 years registered with the civil authority (%)': 'death_registered',
    'Population living in households with electricity (%)': 'electricity',
    'Population living in households with an improved drinking-water source1 (%)': 'improved_water',
    'Population living in households that use an improved sanitation facility2 (%)': 'improved_sanitation',
    'Households using clean fuel for cooking3 (%)': 'clean_fuel',
    'Households using iodized salt (%)': 'iodized_salt',
    'Households with any usual member covered under a health insurance/financing scheme (%)': 'health_insurance',
    'Children age 5 years who attended pre-primary school during the school year 2019-20 (%)': 'pre_primary',

    # Education & Internet
    'Women (age 15-49) who are literate4 (%)': 'women_literate',
    'Men (age 15-49) who are literate4 (%)': 'men_literate',
    'Women (age 15-49)  with 10 or more years of schooling (%)': 'women_10plus_edu',
    'Men (age 15-49)  with 10 or more years of schooling (%)': 'men_10plus_edu',
    'Women (age 15-49)  who have ever used the internet (%)': 'women_internet',
    'Men (age 15-49)  who have ever used the internet (%)': 'men_internet',

    # Marriage, Fertility & Mortality
    'Women age 20-24 years married before age 18 years (%)': 'women_married_18',
    'Men age 25-29 years married before age 21 years (%)': 'men_married_21',
    'Total Fertility Rate (number of children per woman)': 'tfr',
    'Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)': 'teen_mother',
    'Adolescent fertility rate for women age 15-19 years5': 'adolescent_fertility_rate',
    'Neonatal mortality rate (per 1000 live births)': 'neonatal_mr',
    'Infant mortality rate (per 1000 live births)': 'infant_mr',
    'Under-five mortality rate (per 1000 live births)': 'under5_mr',

    # Family Planning
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Any method6 (%)': 'fp_any',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Any modern method6 (%)': 'fp_modern',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Female sterilization (%)': 'fp_female_ster',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Male sterilization (%)': 'fp_male_ster',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - IUD/PPIUD (%)': 'fp_iud',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Pill (%)': 'fp_pill',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Condom (%)': 'fp_condom',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Injectables (%)': 'fp_inject',
    'Total Unmet need for Family Planning (Currently Married Women Age 15-49  years)7 (%)': 'unmet_fp_total',
    'Unmet need for spacing (Currently Married Women Age 15-49  years)7 (%)': 'unmet_spacing',
    'Health worker ever talked to female non-users about family planning (%)': 'hw_fp_talk',
    'Current users ever told about side effects of current method of family planning8 (%)': 'fp_side_effects_told',

    # Maternal & Child Health
    'Mothers who had an antenatal check-up in the first trimester  (for last birth in the 5 years before the survey) (%)': 'anc_1st_tri',
    'Mothers who had at least 4 antenatal care visits  (for last birth in the 5 years before the survey) (%)': 'anc_4plus',
    'Mothers whose last birth was protected against neonatal tetanus (for last birth in the 5 years before the survey)9 (%)': 'tetanus_protect',
    'Mothers who consumed iron folic acid for 100 days or more when they were pregnant (for last birth in the 5 years before the survey) (%)': 'ifa_100days',
    'Mothers who consumed iron folic acid for 180 days or more when they were pregnant (for last birth in the 5 years before the survey} (%)': 'ifa_180days',
    'Registered pregnancies for which the mother received a Mother and Child Protection (MCP) card (for last birth in the 5 years before the survey) (%)': 'mcp_card',
    'Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (for last birth in the 5 years before the survey) (%)': 'pnc_mother_2days',
    'Average out-of-pocket expenditure per delivery in a public health facility (for last birth in the 5 years before the survey) (Rs.)': 'oop_delivery_public',
    'Children born at home who were taken to a health facility for a check-up within 24 hours of birth (for last birth in the 5 years before the survey} (%)': 'pnc_home_child_24hr',
    'Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/ other health personnel within 2 days of delivery (for last birth in the 5 years before the survey) (%)': 'pnc_child_2days',

    # Delivery & Caesarean
    'Institutional births (in the 5 years before the survey) (%)': 'inst_birth',
    'Institutional births in public facility (in the 5 years before the survey) (%)': 'inst_birth_public',
    'Home births that were conducted by skilled health personnel  (in the 5 years before the survey)10 (%)': 'skilled_home_birth',
    'Births attended by skilled health personnel (in the 5 years before the survey)10 (%)': 'skilled_birth',
    'Births delivered by caesarean section (in the 5 years before the survey) (%)': 'csection_total',
    'Births in a private health facility that were delivered by caesarean section (in the 5 years before the survey) (%)': 'csection_private',
    'Births in a public health facility that were delivered by caesarean section (in the 5 years before the survey) (%)': 'csection_public',

    # Vaccination
    'Children age 12-23 months fully vaccinated based on information from either vaccination card or mother\'s recall11 (%)': 'full_vac_card_mother',
    'Children age 12-23 months fully vaccinated based on information from vaccination card only12 (%)': 'full_vac_card_only',
    'Children age 12-23 months who have received BCG (%)': 'bcg',
    'Children age 12-23 months who have received 3 doses of polio vaccine13 (%)': 'polio_3',
    'Children age 12-23 months who have received 3 doses of penta or DPT vaccine (%)': 'penta_dpt_3',
    'Children age 12-23 months who have received the first dose of measles-containing vaccine (MCV) (%)': 'mcv1',
    'Children age 24-35 months who have received a second dose of measles-containing vaccine (MCV) (%)': 'mcv2',
    'Children age 12-23 months who have received 3 doses of rotavirus vaccine14 (%)': 'rota_3',
    'Children age 12-23 months who have received 3 doses of penta or hepatitis B vaccine (%)': 'hepb_3',
    'Children age 9-35 months who received a vitamin A dose in the last 6 months (%)': 'vit_a_6m',
    'Children age 12-23 months who received most of their vaccinations in a public health facility (%)': 'vac_most_public',
    'Children age 12-23 months who received most of their vaccinations in a private health facility (%)': 'vac_most_private',

    # Morbidity (Diarrhoea, ARI)
    'Prevalence of diarrhoea in the 2 weeks preceding the survey (Children under age 5 years) (%)': 'diarrhoea_prev',
    'Children with diarrhoea in the 2 weeks preceding the survey who received oral rehydration salts (ORS) (Children under age 5 years) (%)': 'ors',
    'Children with diarrhoea in the 2 weeks preceding the survey who received zinc (Children under age 5 years) (%)': 'zinc',
    'Children swith diarrhoea in the 2 weeks preceding the survey taken to a health facility or health provider (Children under age 5 years) (%)': 'diarrhoea_facility',
    'Children Prevalence of symptoms of acute respiratory infection (ARI) in the 2 weeks preceding the survey (Children under age 5 years) (%)': 'ari_prev',
    'Children with fever or symptoms of ARI in the 2 weeks preceding the survey taken to a health facility or health provider (Children under age 5 years) (%)': 'ari_facility',

    # Breastfeeding & Nutrition
    'Children under age 3 years breastfed within one hour of birth15 (%)': 'bf_within_1hr',
    'Children under age 6 months exclusively breastfed16 (%)': 'ebf_6m',
    'Children age 6-8 months receiving solid or semi-solid food and breastmilk16 (%)': 'comp_feed_6_8m',
    'Breastfeeding children age 6-23 months receiving an adequate diet16, 17  (%)': 'bf_adequate_diet',
    'Non-breastfeeding children age 6-23 months receiving an adequate diet16, 17 (%)': 'nonbf_adequate_diet',
    'Total children age 6-23 months receiving an adequate diet16, 17  (%)': 'total_adequate_diet',
    'Children under 5 years who are stunted (height-for-age)18 (%)': 'stunted_u5',
    'Children under 5 years who are wasted (weight-for-height)18 (%)': 'wasted_u5',
    'Children under 5 years who are severely wasted (weight-for-height)19 (%)': 'sev_wasted_u5',
    'Children under 5 years who are underweight (weight-for-age)18 (%)': 'underweight_u5',
    'Children under 5 years who are overweight (weight-for-height)20 (%)': 'overweight_u5',

    # BMI, Anaemia, Blood Sugar, Blood Pressure
    'Women (age 15-49 years) whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2)21 (%)': 'bmi_low_women',
    'Men (age 15-49 years) whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2) (%)': 'bmi_low_men',
    'Women (age 15-49 years) who are overweight or obese (BMI ≥25.0 kg/m2)21 (%)': 'bmi_high_women',
    'Men (age 15-49 years) who are overweight or obese (BMI ≥25.0 kg/m2) (%)': 'bmi_high_men',
    'Women (age 15-49 years) who have high risk waist-to-hip ratio (≥0.85) (%)': 'whr_high_women',
    'Men (age 15-49 years) who have high risk waist-to-hip ratio (≥0.90) (%)': 'whr_high_men',
    'Children age 6-59 months who are anaemic (<11.0 g/dl)22 (%)': 'anaemia_child',
    'Non-pregnant women age 15-49 years who are anaemic (<12.0 g/dl)22 (%)': 'anaemia_nonpreg_women',
    'Pregnant women age 15-49 years who are anaemic (<11.0 g/dl)22 (%)': 'anaemia_preg_women',
    'All women age 15-49 years who are anaemic22 (%)': 'anaemia_all_women',
    'All women age 15-19 years who are anaemic22 (%)': 'anaemia_teen_women',
    'Men age 15-49 years who are anaemic (<13.0 g/dl)22 (%)': 'anaemia_men',
    'Men age 15-19 years who are anaemic (<13.0 g/dl)22 (%)': 'anaemia_teen_men',

    # Blood Sugar
    'Women  age 15 years and above with high (141-160 mg/dl) Blood sugar level23 (%)': 'bs_high_women',
    'Women age 15 years and above wih very high (>160 mg/dl) Blood sugar level23 (%)': 'bs_veryhigh_women',
    'Women age 15 years and above wih high or very high (>140 mg/dl) Blood sugar level or taking medicine to control blood sugar level23 (%)': 'bs_high_or_med_women',
    'Men age 15 years and above wih high (141-160 mg/dl) Blood sugar level23 (%)': 'bs_high_men',
    'Men (age 15 years and above wih  very high (>160 mg/dl) Blood sugar level23 (%)': 'bs_veryhigh_men',
    'Men age 15 years and above wih high or very high (>140 mg/dl) Blood sugar level  or taking medicine to control blood sugar level23 (%)': 'bs_high_or_med_men',

    # Blood Pressure
    'Women age 15 years and above wih Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)': 'bp_mild_elev_women',
    'Women age 15 years and above wih Moderately or severely elevated blood pressure (Systolic ≥160 mm of Hg and/or Diastolic ≥100 mm of Hg) (%)': 'bp_mod_sev_elev_women',
    'Women age 15 years and above wih Elevated blood pressure (Systolic ≥140 mm of Hg and/or Diastolic ≥90 mm of Hg) or taking medicine to control blood pressure (%)': 'bp_elev_or_med_women',
    'Men age 15 years and above wih Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)': 'bp_mild_elev_men',
    'Men age 15 years and above wih Moderately or severely elevated blood pressure (Systolic ≥160 mm of Hg and/or Diastolic ≥100 mm of Hg) (%)': 'bp_mod_sev_elev_men',
    'Men age 15 years and above wih Elevated blood pressure (Systolic ≥140 mm of Hg and/or Diastolic ≥90 mm of Hg) or taking medicine to control blood pressure (%)': 'bp_elev_or_med_men',

    # Cancer Screening
    'Women (age 30-49 years) Ever undergone a screening test for cervical cancer (%)': 'cervical_screen',
    'Women (age 30-49 years) Ever undergone a breast examination for breast cancer (%)': 'breast_exam',
    'Women (age 30-49 years) Ever undergone an oral cavity examination for oral cancer (%)': 'oral_exam_women',
    'Men (age 30-49 years)Ever undergone an oral cavity examination for oral cancer (%)': 'oral_exam_men',

    # HIV Knowledge
    'Women (age 15-49 years) who have comprehensive knowledge24 of HIV/AIDS (%)': 'hiv_knowledge_women',
    'Men (age 15-49 years) who have comprehensive knowledge24 of HIV/AIDS (%)': 'hiv_knowledge_men',
    'Women (age 15-49 years) who know that consistent condom use can reduce the chance of getting HIV/AIDS (%)': 'hiv_condom_knowledge_women',
    'Men (age 15-49 years) who know that consistent condom use can reduce the chance of getting HIV/AIDS (%)': 'hiv_condom_knowledge_men',

    # Women Empowerment
    'Currently married women (age 15-49 years) who usually participate in three household decisions25 (%)': 'women_household_decision',
    'Women (age 15-49 years) who worked in the last 12 months and were paid in cash (%)': 'women_paid_work',
    'Women (age 15-49 years) owning a house and/or land (alone or jointly with others) (%)': 'women_own_house_land',
    'Women (age 15-49 years) having a bank or savings account that they themselves use (%)': 'women_bank_account',
    'Women (age 15-49 years) having a mobile phone that they themselves use (%)': 'women_mobile_phone',

    # Menstrual Hygiene
    'Women age 15-24 years who use hygienic methods of protection during their menstrual period26 (%)': 'hygienic_menstrual',

    # Violence
    'Ever-married women age 18-49 years who have ever experienced spousal violence27 (%)': 'spousal_violence',
    'Ever-married women age 18-49 years who have experienced physical violence during any pregnancy (%)': 'violence_pregnancy',
    'Young women age 18-29 years who experienced sexual violence by age 18 (%)': 'sexual_violence_young',

    # Tobacco & Alcohol
    'Women age 15 years and above who use any kind of tobacco (%)': 'tobacco_women',
    'Men age 15 years and above who use any kind of tobacco (%)': 'tobacco_men',
    'Women age 15 years and above who consume alcohol (%)': 'alcohol_women',
    'Men age 15 years and above who consume alcohol (%)': 'alcohol_men'
}

# %%
nfhs_state = pd.read_csv('nfhs5_state_detailed.csv', low_memory=False)
nfhs_state = nfhs_state.rename(columns=state_detailed_rename)

# %%
nfhs_state.head()
# Out:
#                     state_ut   area  Number of Households surveyed  \
# 0                      India  Urban                         160138
# 1                      India  Rural                         476561
# 2                      India  Total                         636699
# 3  Andaman & Nicobar Islands  Urban                            527
# 4  Andaman & Nicobar Islands  Rural                           2097
#
#    Number of Women age 15-49 years interviewed  \
# 0                                       179535
# 1                                       544580
# 2                                       724115
# 3                                          557
# 4                                         1840
#
#    Number of Men age 15-54 years interviewed female_school_6plus  \
# 0                                      26420               82.5
# 1                                      75419               66.8
# 2                                     101839               71.8
# ...

# %%
district_rename = {
    'District Names': 'district',
    'State/UT': 'state_ut',
    'Number of Households surveyed': 'hh_surveyed',
    'Number of Women age 15-49 years interviewed': 'women_15_49',
    'Number of Men age 15-54 years interviewed': 'men_15_54',
    
    # Demographics & Basic Infrastructure
    'Female population age 6 years and above who ever attended school (%)': 'female_school_6plus',
    'Population below age 15 years (%)': 'pop_below_15',
    'Sex ratio of the total population (females per 1,000 males)': 'sex_ratio_total',
    'Sex ratio at birth for children born in the last five years (females per 1,000 males)': 'sex_ratio_birth',
    'Children under age 5 years whose birth was registered with the civil authority (%)': 'birth_registered',
    'Deaths in the last 3 years registered with the civil authority (%)': 'death_registered',
    'Population living in households with electricity (%)': 'electricity',
    'Population living in households with an improved drinking-water source1 (%)': 'improved_water',
    'Population living in households that use an improved sanitation facility2 (%)': 'improved_sanitation',
    'Households using clean fuel for cooking3 (%)': 'clean_fuel',
    'Households using iodized salt (%)': 'iodized_salt',
    'Households with any usual member covered under a health insurance/financing scheme (%)': 'health_insurance',
    'Children age 5 years who attended pre-primary school during the school year 2019-20 (%)': 'pre_primary',

    # Education & Literacy
    'Women (age 15-49) who are literate4 (%)': 'women_literate',
    'Women (age 15-49)  with 10 or more years of schooling (%)': 'women_10plus_edu',
    'Women age 20-24 years married before age 18 years (%)': 'women_married_18',
    'Women age 15-19 years who were already mothers or pregnant at the time of the survey (%)': 'teen_mother',
    'Women age 15-24 years who use hygienic methods of protection during their menstrual period5 (%)': 'hygienic_menstrual',

    # Family Planning
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Any method6 (%)': 'fp_any',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Any modern method6 (%)': 'fp_modern',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Female sterilization (%)': 'fp_female_ster',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Male sterilization (%)': 'fp_male_ster',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - IUD/PPIUD (%)': 'fp_iud',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Pill (%)': 'fp_pill',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Condom (%)': 'fp_condom',
    'Current Use of Family Planning Methods (Currently Married Women Age 15-49  years) - Injectables (%)': 'fp_inject',
    'Total Unmet need for Family Planning (Currently Married Women Age 15-49  years)7 (%)': 'unmet_fp_total',
    'Unmet need for spacing (Currently Married Women Age 15-49  years)7 (%)': 'unmet_spacing',
    'Health worker ever talked to female non-users about family planning (%)': 'hw_fp_talk',
    'Current users ever told about side effects of current method of family planning8 (%)': 'fp_side_effects_told',

    # Maternal Health
    'Mothers who had an antenatal check-up in the first trimester  (for last birth in the 5 years before the survey) (%)': 'anc_1st_tri',
    'Mothers who had at least 4 antenatal care visits  (for last birth in the 5 years before the survey) (%)': 'anc_4plus',
    'Mothers whose last birth was protected against neonatal tetanus (for last birth in the 5 years before the survey)9 (%)': 'tetanus_protect',
    'Mothers who consumed iron folic acid for 100 days or more when they were pregnant (for last birth in the 5 years before the survey) (%)': 'ifa_100days',
    'Mothers who consumed iron folic acid for 180 days or more when they were pregnant (for last birth in the 5 years before the survey} (%)': 'ifa_180days',
    'Registered pregnancies for which the mother received a Mother and Child Protection (MCP) card (for last birth in the 5 years before the survey) (%)': 'mcp_card',
    'Mothers who received postnatal care from a doctor/nurse/LHV/ANM/midwife/other health personnel within 2 days of delivery (for last birth in the 5 years before the survey) (%)': 'pnc_mother_2days',
    'Average out-of-pocket expenditure per delivery in a public health facility (for last birth in the 5 years before the survey) (Rs.)': 'oop_delivery_public',
    'Children born at home who were taken to a health facility for a check-up within 24 hours of birth (for last birth in the 5 years before the survey} (%)': 'pnc_home_child_24hr',
    'Children who received postnatal care from a doctor/nurse/LHV/ANM/midwife/ other health personnel within 2 days of delivery (for last birth in the 5 years before the survey) (%)': 'pnc_child_2days',

    # Delivery & Caesarean
    'Institutional births (in the 5 years before the survey) (%)': 'inst_birth',
    'Institutional births in public facility (in the 5 years before the survey) (%)': 'inst_birth_public',
    'Home births that were conducted by skilled health personnel  (in the 5 years before the survey)10 (%)': 'skilled_home_birth',
    'Births attended by skilled health personnel (in the 5 years before the survey)10 (%)': 'skilled_birth',
    'Births delivered by caesarean section (in the 5 years before the survey) (%)': 'csection_total',
    'Births in a private health facility that were delivered by caesarean section (in the 5 years before the survey) (%)': 'csection_private',
    'Births in a public health facility that were delivered by caesarean section (in the 5 years before the survey) (%)': 'csection_public',

    # Vaccination
    'Children age 12-23 months fully vaccinated based on information from either vaccination card or mother\'s recall11 (%)': 'full_vac_card_mother',
    'Children age 12-23 months fully vaccinated based on information from vaccination card only12 (%)': 'full_vac_card_only',
    'Children age 12-23 months who have received BCG (%)': 'bcg',
    'Children age 12-23 months who have received 3 doses of polio vaccine13 (%)': 'polio_3',
    'Children age 12-23 months who have received 3 doses of penta or DPT vaccine (%)': 'penta_dpt_3',
    'Children age 12-23 months who have received the first dose of measles-containing vaccine (MCV) (%)': 'mcv1',
    'Children age 24-35 months who have received a second dose of measles-containing vaccine (MCV) (%)': 'mcv2',
    'Children age 12-23 months who have received 3 doses of rotavirus vaccine14 (%)': 'rota_3',
    'Children age 12-23 months who have received 3 doses of penta or hepatitis B vaccine (%)': 'hepb_3',
    'Children age 9-35 months who received a vitamin A dose in the last 6 months (%)': 'vit_a_6m',
    'Children age 12-23 months who received most of their vaccinations in a public health facility (%)': 'vac_most_public',
    'Children age 12-23 months who received most of their vaccinations in a private health facility (%)': 'vac_most_private',

    # Morbidity (Diarrhoea & ARI)
    'Prevalence of diarrhoea in the 2 weeks preceding the survey (Children under age 5 years) (%)': 'diarrhoea_prev',
    'Children with diarrhoea in the 2 weeks preceding the survey who received oral rehydration salts (ORS) (Children under age 5 years) (%)': 'ors',
    'Children with diarrhoea in the 2 weeks preceding the survey who received zinc (Children under age 5 years) (%)': 'zinc',
    'Children swith diarrhoea in the 2 weeks preceding the survey taken to a health facility or health provider (Children under age 5 years) (%)': 'diarrhoea_facility',
    'Children Prevalence of symptoms of acute respiratory infection (ARI) in the 2 weeks preceding the survey (Children under age 5 years) (%)': 'ari_prev',
    'Children with fever or symptoms of ARI in the 2 weeks preceding the survey taken to a health facility or health provider (Children under age 5 years) (%)': 'ari_facility',

    # Breastfeeding & Child Diet
    'Children under age 3 years breastfed within one hour of birth15 (%)': 'bf_within_1hr',
    'Children under age 6 months exclusively breastfed16 (%)': 'ebf_6m',
    'Children age 6-8 months receiving solid or semi-solid food and breastmilk16 (%)': 'comp_feed_6_8m',
    'Breastfeeding children age 6-23 months receiving an adequate diet16, 17  (%)': 'bf_adequate_diet',
    'Non-breastfeeding children age 6-23 months receiving an adequate diet16, 17 (%)': 'nonbf_adequate_diet',
    'Total children age 6-23 months receiving an adequate diet16, 17  (%)': 'total_adequate_diet',

    # Nutrition Indicators
    'Children under 5 years who are stunted (height-for-age)18 (%)': 'stunted_u5',
    'Children under 5 years who are wasted (weight-for-height)18 (%)': 'wasted_u5',
    'Children under 5 years who are severely wasted (weight-for-height)19 (%)': 'sev_wasted_u5',
    'Children under 5 years who are underweight (weight-for-age)18 (%)': 'underweight_u5',
    'Children under 5 years who are overweight (weight-for-height)20 (%)': 'overweight_u5',

    # BMI, Anaemia, Blood Sugar, Blood Pressure, Tobacco & Alcohol
    'Women (age 15-49 years) whose Body Mass Index (BMI) is below normal (BMI <18.5 kg/m2)21 (%)': 'bmi_low_women',
    'Women (age 15-49 years) who are overweight or obese (BMI ≥25.0 kg/m2)21 (%)': 'bmi_high_women',
    'Women (age 15-49 years) who have high risk waist-to-hip ratio (≥0.85) (%)': 'whr_high_women',
    'Children age 6-59 months who are anaemic (<11.0 g/dl)22 (%)': 'anaemia_child',
    'Non-pregnant women age 15-49 years who are anaemic (<12.0 g/dl)22 (%)': 'anaemia_nonpreg_women',
    'Pregnant women age 15-49 years who are anaemic (<11.0 g/dl)22 (%)': 'anaemia_preg_women',
    'All women age 15-49 years who are anaemic22 (%)': 'anaemia_all_women',
    'All women age 15-19 years who are anaemic22 (%)': 'anaemia_teen_women',

    # Blood Sugar
    'Women  age 15 years and above with high (141-160 mg/dl) Blood sugar level23 (%)': 'bs_high_women',
    'Women age 15 years and above wih very high (>160 mg/dl) Blood sugar level23 (%)': 'bs_veryhigh_women',
    'Women age 15 years and above wih high or very high (>140 mg/dl) Blood sugar level or taking medicine to control blood sugar level23 (%)': 'bs_high_or_med_women',
    'Men age 15 years and above wih high (141-160 mg/dl) Blood sugar level23 (%)': 'bs_high_men',
    'Men (age 15 years and above wih  very high (>160 mg/dl) Blood sugar level23 (%)': 'bs_veryhigh_men',
    'Men age 15 years and above wih high or very high (>140 mg/dl) Blood sugar level  or taking medicine to control blood sugar level23 (%)': 'bs_high_or_med_men',

    # Blood Pressure
    'Women age 15 years and above wih Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)': 'bp_mild_elev_women',
    'Women age 15 years and above wih Moderately or severely elevated blood pressure (Systolic ≥160 mm of Hg and/or Diastolic ≥100 mm of Hg) (%)': 'bp_mod_sev_elev_women',
    'Women age 15 years and above wih Elevated blood pressure (Systolic ≥140 mm of Hg and/or Diastolic ≥90 mm of Hg) or taking medicine to control blood pressure (%)': 'bp_elev_or_med_women',
    'Men age 15 years and above wih Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)': 'bp_mild_elev_men',
    'Men age 15 years and above wih Moderately or severely elevated blood pressure (Systolic ≥160 mm of Hg and/or Diastolic ≥100 mm of Hg) (%)': 'bp_mod_sev_elev_men',
    'Men age 15 years and above wih Elevated blood pressure (Systolic ≥140 mm of Hg and/or Diastolic ≥90 mm of Hg) or taking medicine to control blood pressure (%)': 'bp_elev_or_med_men',

    # Cancer Screening & Risk Factors
    'Women (age 30-49 years) Ever undergone a screening test for cervical cancer (%)': 'cervical_screen',
    'Women (age 30-49 years) Ever undergone a breast examination for breast cancer (%)': 'breast_exam',
    'Women (age 30-49 years) Ever undergone an oral cavity examination for oral cancer (%)': 'oral_exam_women',
    'Women age 15 years and above who use any kind of tobacco (%)': 'tobacco_women',
    'Men age 15 years and above who use any kind of tobacco (%)': 'tobacco_men',
    'Women age 15 years and above who consume alcohol (%)': 'alcohol_women',
    'Men age 15 years and above who consume alcohol (%)': 'alcohol_men'
}

# %%
nfhs_district = pd.read_csv('nfhs5_district_detailed.csv', low_memory=False)

nfhs_district = nfhs_district.rename(columns=district_rename)

# %%
nfhs_district.head()
# Out:
#                   district                   state_ut  hh_surveyed  \
# 0                 Nicobars  Andaman & Nicobar Islands          882
# 1  North & Middle Andaman   Andaman & Nicobar Islands          874
# 2           South Andaman   Andaman & Nicobar Islands          868
# 3              Srikakulam              Andhra Pradesh          874
# 4            Vizianagaram              Andhra Pradesh          902
#
#    women_15_49  men_15_54  female_school_6plus  pop_below_15  \
# 0          764        125                 78.0          23.0
# 1          789        108                 82.7          19.8
# 2          844        134                 84.7          20.9
# 3          780        100                 60.0          20.7
# 4          853        134                 56.0          20.6
#
#     Sex ratio of the total population (females per 1,000 males)  \
# 0                                                973
# 1                                                950
# ...

# %%
nfhs_district = nfhs_district.rename(columns=district_rename)
nfhs_state = nfhs_state.rename(columns=state_detailed_rename)
poshan = poshan.rename(columns=poshan_rename)
infra = infra.rename(columns=infra_rename)
claims = claims.rename(columns=claims_rename)

# %%
nfhs_district.columns.tolist()
# Out:
# ['district',
#  'state_ut',
#  'hh_surveyed',
#  'women_15_49',
#  'men_15_54',
#  'female_school_6plus',
#  'pop_below_15',
#  ' Sex ratio of the total population (females per 1,000 males)',
#  'sex_ratio_birth',
#  'birth_registered',
#  'death_registered',
#  'electricity',
#  'improved_water',
#  'improved_sanitation',
#  'clean_fuel',
#  'iodized_salt',
#  'health_insurance',
#  'pre_primary',
#  'women_literate',
#  'women_10plus_edu',
#  'women_married_18',
#  'Births in the 5 years preceding the survey that are third or higher order (%)',
#  'teen_mother',
#  'hygienic_menstrual',
#  'fp_any',
#  'fp_modern',
#  'fp_female_ster',
#  'fp_male_ster',
#  'fp_iud',
#  'fp_pill',
#  'fp_condom',
#  'fp_inject',
#  'unmet_fp_total',
#  'unmet_spacing',
#  'hw_fp_talk',
#  'fp_side_effects_told',
#  'anc_1st_tri',
#  'anc_4plus',
#  'tetanus_protect',
#  'ifa_100days',
#  'ifa_180days',
#  'mcp_card',
#  'pnc_mother_2days',
#  'oop_delivery_public',
#  'pnc_home_child_24hr',
# ...

# %%
cleanup_rename = {
    ' Sex ratio of the total population (females per 1,000 males)': 'sex_ratio_total',
    'Births in the 5 years preceding the survey that are third or higher order (%)': 'births_3plus',
    'Prevalence of diarrhoea in the 2 weeks preceding the survey (Children under age 5 years) (%) ': 'diarrhoea_prev',
    'Children with diarrhoea in the 2 weeks preceding the survey who received oral rehydration salts (ORS) (Children under age 5 years) (%) ': 'ors',
    'Children with diarrhoea in the 2 weeks preceding the survey who received zinc (Children under age 5 years) (%) ': 'zinc',
    'Children swith diarrhoea in the 2 weeks preceding the survey taken to a health facility or health provider (Children under age 5 years) (%) ': 'diarrhoea_facility',
    'Children Prevalence of symptoms of acute respiratory infection (ARI) in the 2 weeks preceding the survey (Children under age 5 years) (%) ': 'ari_prev',
    'Children with fever or symptoms of ARI in the 2 weeks preceding the survey taken to a health facility or health provider (Children under age 5 years) (%)  ': 'ari_facility',
    'All women age 15-19 years who are anaemic22 (%) ': 'anaemia_teen_women',
}

nfhs_district = nfhs_district.rename(columns=cleanup_rename)
nfhs_district.columns = nfhs_district.columns.str.strip()

# %%
nfhs_district.columns.tolist()
# Out:
# ['district',
#  'state_ut',
#  'hh_surveyed',
#  'women_15_49',
#  'men_15_54',
#  'female_school_6plus',
#  'pop_below_15',
#  'sex_ratio_total',
#  'sex_ratio_birth',
#  'birth_registered',
#  'death_registered',
#  'electricity',
#  'improved_water',
#  'improved_sanitation',
#  'clean_fuel',
#  'iodized_salt',
#  'health_insurance',
#  'pre_primary',
#  'women_literate',
#  'women_10plus_edu',
#  'women_married_18',
#  'births_3plus',
#  'teen_mother',
#  'hygienic_menstrual',
#  'fp_any',
#  'fp_modern',
#  'fp_female_ster',
#  'fp_male_ster',
#  'fp_iud',
#  'fp_pill',
#  'fp_condom',
#  'fp_inject',
#  'unmet_fp_total',
#  'unmet_spacing',
#  'hw_fp_talk',
#  'fp_side_effects_told',
#  'anc_1st_tri',
#  'anc_4plus',
#  'tetanus_protect',
#  'ifa_100days',
#  'ifa_180days',
#  'mcp_card',
#  'pnc_mother_2days',
#  'oop_delivery_public',
#  'pnc_home_child_24hr',
#  'pnc_child_2days',
#  'inst_birth',
#  'inst_birth_public',
#  'skilled_home_birth',
#  'skilled_birth',
# ...

# %%
# Cleanup for remaining long column names in state detailed file
state_cleanup_rename = {
    'Number of Households surveyed': 'hh_surveyed',
    'Number of Women age 15-49 years interviewed': 'women_15_49',
    'Number of Men age 15-54 years interviewed': 'men_15_54',
    ' Sex ratio of the total population (females per 1,000 males)': 'sex_ratio_total',
    
    # Diarrhoea & ARI
    'Prevalence of diarrhoea in the 2 weeks preceding the survey (Children under age 5 years) (%) ': 'diarrhoea_prev',
    'Children with diarrhoea in the 2 weeks preceding the survey who received oral rehydration salts (ORS) (Children under age 5 years) (%) ': 'ors',
    'Children with diarrhoea in the 2 weeks preceding the survey who received zinc (Children under age 5 years) (%) ': 'zinc',
    'Children swith diarrhoea in the 2 weeks preceding the survey taken to a health facility or health provider (Children under age 5 years) (%) ': 'diarrhoea_facility',
    'Children Prevalence of symptoms of acute respiratory infection (ARI) in the 2 weeks preceding the survey (Children under age 5 years) (%) ': 'ari_prev',
    'Children with fever or symptoms of ARI in the 2 weeks preceding the survey taken to a health facility or health provider (Children under age 5 years) (%)  ': 'ari_facility',
    
    # Anaemia
    'All women age 15-19 years who are anaemic22 (%) ': 'anaemia_teen_women',
    
    # Drop useless column
    'Unnamed: 136': 'unnamed_col'
}

# %%
# After loading and initial rename
nfhs_state = nfhs_state.rename(columns=state_cleanup_rename)

# Final strip any extra spaces
nfhs_state.columns = nfhs_state.columns.str.strip()

# Drop useless column
if 'unnamed_col' in nfhs_state.columns:
    nfhs_state = nfhs_state.drop(columns=['unnamed_col'])

print("✅ State file cleanup done!")
print(nfhs_state.columns.tolist())
# Out:
# ✅ State file cleanup done!
# ...

# %%
nfhs_state.columns.tolist()
# Out:
# ['state_ut',
#  'area',
#  'hh_surveyed',
#  'women_15_49',
#  'men_15_54',
#  'female_school_6plus',
#  'pop_below_15',
#  'sex_ratio_total',
#  'sex_ratio_birth',
#  'birth_registered',
#  'death_registered',
#  'electricity',
#  'improved_water',
#  'improved_sanitation',
#  'clean_fuel',
#  'iodized_salt',
#  'health_insurance',
#  'pre_primary',
#  'women_literate',
#  'men_literate',
#  'women_10plus_edu',
#  'men_10plus_edu',
#  'women_internet',
#  'men_internet',
#  'women_married_18',
#  'men_married_21',
#  'tfr',
#  'teen_mother',
#  'adolescent_fertility_rate',
#  'neonatal_mr',
#  'infant_mr',
#  'under5_mr',
#  'fp_any',
#  'fp_modern',
#  'fp_female_ster',
#  'fp_male_ster',
#  'fp_iud',
#  'fp_pill',
#  'fp_condom',
#  'fp_inject',
#  'unmet_fp_total',
#  'unmet_spacing',
#  'hw_fp_talk',
#  'fp_side_effects_told',
#  'anc_1st_tri',
#  'anc_4plus',
#  'tetanus_protect',
#  'ifa_100days',
#  'ifa_180days',
#  'mcp_card',
#  'pnc_mother_2days',
# ...

# %%
state_nutrition_rename = {
    'State/Union Territory': 'state_ut',
    'Stunted (Height-for-age)1': 'stunted_nfhs',
    'Wasted (Weight-for-Height)1': 'wasted_nfhs',
    'Underweight (Weight-for-Age)1': 'underweight_nfhs'
}

# %%
state_nutrition = pd.read_csv('nfhs5_state_nutrition.csv')
state_nutrition = state_nutrition.rename(columns=state_nutrition_rename)

# %%
state_nutrition.columns.tolist()
# Out:
# ['state_ut', 'stunted_nfhs', 'wasted_nfhs', 'underweight_nfhs']

# %%
state_nutrition.isnull().sum()
# Out:
# state_ut            0
# stunted_nfhs        0
# wasted_nfhs         0
# underweight_nfhs    0
# dtype: int64

# %%
nfhs_state.isnull().sum()
# Out:
# state_ut                 0
# area                     0
# hh_surveyed              0
# women_15_49              0
# men_15_54                0
#                         ..
# sexual_violence_young    0
# tobacco_women            0
# tobacco_men              0
# alcohol_women            0
# alcohol_men              0
# Length: 136, dtype: int64

# %%
nfhs_district.isnull().sum()
# Out:
# district           0
# state_ut           0
# hh_surveyed        0
# women_15_49        0
# men_15_54          0
#                   ..
# oral_exam_women    0
# tobacco_women      0
# tobacco_men        0
# alcohol_women      0
# alcohol_men        0
# Length: 109, dtype: int64

# %%
poshan.isnull().sum()
# Out:
# state_ut               0
# stunted_oct2022        0
# wasted_oct2022         0
# underweight_oct2022    0
# stunted_oct2023        0
# wasted_oct2023         0
# underweight_oct2023    0
# stunted_oct2024        0
# wasted_oct2024         0
# underweight_oct2024    0
# dtype: int64

# %%
infra.isnull().sum()
# Out:
# state_ut             0
# phc                  0
# chc                  1
# sub_district_hosp    8
# district_hosp        0
# medical_college      4
# total_beds           0
# dtype: int64

# %%
claims.isnull().sum()
# Out:
# state_ut               0
# claims_sub_2020_21     3
# claims_paid_2020_21    3
# claims_pend_2020_21    8
# claims_sub_2021_22     0
# claims_paid_2021_22    0
# claims_pend_2021_22    2
# claims_sub_2022_23     0
# claims_paid_2022_23    0
# claims_pend_2022_23    1
# dtype: int64

# %%
nfhs_district.isnull().sum()
# Out:
# district           0
# state_ut           0
# hh_surveyed        0
# women_15_49        0
# men_15_54          0
#                   ..
# oral_exam_women    0
# tobacco_women      0
# tobacco_men        0
# alcohol_women      0
# alcohol_men        0
# Length: 109, dtype: int64

# %%
nfhs_state.isnull().sum()
# Out:
# state_ut                 0
# area                     0
# hh_surveyed              0
# women_15_49              0
# men_15_54                0
#                         ..
# sexual_violence_young    0
# tobacco_women            0
# tobacco_men              0
# alcohol_women            0
# alcohol_men              0
# Length: 136, dtype: int64

# %%
nfhs_district.isnull().sum().sum()
nfhs_state.isnull().sum().sum()
poshan.isnull().sum().sum()
infra.isnull().sum().sum()
claims.isnull().sum().sum()
state_nutrition.isnull().sum().sum()
# Out:
# 0

# %%
dfs = [nfhs_district, nfhs_state, poshan, infra, claims, state_nutrition]

for df in dfs:
    df.drop_duplicates(inplace=True)

# %%
nfhs_district.to_csv("nfhs_district_clean.csv", index=False)
nfhs_state.to_csv("nfhs_state_clean.csv", index=False)
poshan.to_csv("poshan_clean.csv", index=False)
infra.to_csv("infra_clean.csv", index=False)
claims.to_csv("claims_clean.csv", index=False)
state_nutrition.to_csv("state_nutrition_clean.csv", index=False)
